# %%
import pandas as pd
import streamlit as st
import plotly.express as px

# %%
print("Environment working")
# Out:
# Environment working

# %%
df = pd.DataFrame({'City': ['Medellín', 'Lima', 'Nairobi'], 'Visitors': [1.2, 2.5, 3.1]})

# %%
figure = px.bar(df, x='City', y='Visitors', title="Visitors by City")

# %%
figure.show()
